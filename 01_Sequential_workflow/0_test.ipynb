# %%
from langgraph.graph import StateGraph
# Out:
# Running cells with 'ai_engineer (Python 3.11.15)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n ai_engineer ipykernel --update-deps --force-reinstall'
